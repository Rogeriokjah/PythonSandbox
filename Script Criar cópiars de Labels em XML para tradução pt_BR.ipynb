# %%
import xml.etree.ElementTree as ET

# Função para traduzir as labels
def translate_label(label_value):
    translations = {
        "Home": "Início",
        "Search by order account": "Pesquisar por conta de pedido",
        "Access the Complete Schedule": "Acessar o Calendário Completo",
        "Account": "Conta",
        "Create Account": "Criar Conta",
        "Account Creation": "Criação de Conta",
        "Account Editing": "Edição de Conta",
        "Account empty list": "Lista de contas vazia",
        "Account list": "Lista de contas",
        "Account Type": "Tipo de conta",
        "Create": "Criar",
        "Add Application Area": "Adicionar Área de Aplicação",
        "Add area": "Adicionar área",
        "Add bundle": "Adicionar pacote",
        "Add competitor": "Adicionar concorrente",
        "Discount Percentage": "Percentual de Desconto",
        "Discount Value": "Valor de Desconto",
        "Final Total Price": "Preço Total Final",
        "Gross Total Price": "Preço Total Bruto",
        "Order Item Summary": "Resumo do Item do Pedido",
        "Add product": "Adicionar produto",
        "Product added successfully!": "Produto adicionado com sucesso!",
        "Add Productive Area": "Adicionar Área Produtiva",
        "Create Purchase": "Criar Compra",
        "Additional data": "Dados adicionais",
        "Additional Information": "Informações Adicionais",
        "Additional note": "Nota adicional",
        "Advance": "Avançar",
        "Adverts": "Anúncios",
        "After choosing a protocol for this product, evaluations and evaluation items will be automatically created for this test.":
            "Após escolher um protocolo para este produto, as avaliações e itens de avaliação serão criados automaticamente para este teste.",
        "All Account Types": "Todos os Tipos de Conta",
        "All Orders": "Todos os Pedidos",
        "Amount": "Quantidade",
        "Apply filter": "Aplicar filtro",
        "In Progress": "Em Progresso",
        "Not Started": "Não Iniciado",
        "Realized": "Realizado",
        "Approval List": "Lista de Aprovação",
        "Approved ERP": "ERP Aprovado",
        "Approved Salesforce": "Salesforce Aprovado",
        "April": "Abril",
        "Area successfully added!": "Área adicionada com sucesso!",
        "Attachments": "Anexos",
        "Evaluation answered successfully!": "Avaliação respondida com sucesso!",
        "Attach image": "Anexar imagem",
        "Attached files": "Arquivos anexados",
        "Attention!": "Atenção!",
        "August": "Agosto",
        "Unable to authenticate user data": "Não foi possível autenticar os dados do usuário",
        "Branches": "Filiais",
        "Brand saved successfully": "Marca salva com sucesso",
        "Brazil Farmer": "Produtor Brasileiro",
        "Producer Standard": "Padrão do Produtor",
        "Brazil Farmers": "Produtores Brasileiros",
        "Bundle": "Pacote",
        "There are no bundles available...": "Não há pacotes disponíveis...",
        "Bundle total quantity": "Quantidade total do pacote",
        "Bundles": "Pacotes",
        "Calendar": "Calendário",
        "Campaigns": "Campanhas",
        "Bundle list": "Lista de Pacotes",
        "Cancel": "Cancelar",
        "Capture": "Capturar",
        "Capture Responses": "Capturar Respostas",
        "Change": "Alterar",
        "Check your internet connection and try again": "Verifique sua conexão com a internet e tente novamente",
        "Check inventory": "Verificar inventário",
        "Check Required Fields": "Verificar Campos Obrigatórios",
        "City": "Cidade",
        "Classification": "Classificação",
        "Clear URL": "Limpar URL",
        "Click Yes to synchronize": "Clique em Sim para sincronizar",
        "Client": "Cliente",
        "Invalid CNPJ, check it, please": "CNPJ inválido, verifique por favor",
        "Competior Creation": "Criação de Concorrente",
        "Competitor": "Concorrente",
        "Competitor On Farm Creation": "Criação de Concorrente na Fazenda",
        "Competitor On Farm Details": "Detalhes do Concorrente na Fazenda",
        "Conclude": "Concluir",
        "Concluded": "Concluído",
        "Confirmed": "Confirmado",
        "Connection error": "Erro de Conexão",
        "Contact Information": "Informações de Contato",
        "Continue": "Continuar",
        "Cooperatives": "Cooperativas",
        "Invalid CPF, check it, please": "CPF inválido, verifique por favor",
        "Create Account": "Criar Conta",
        "Create Accounting Revenue": "Criar Receita Contábil",
        "Create Digital Profile": "Criar Perfil Digital",
        "Create Event": "Criar Evento",
        "Create Influencer": "Criar Influenciador",
        "Create New Area": "Criar Nova Área",
        "Create Field": "Criar Campo",
        "Create Order": "Criar Pedido",
        "Account Accordion": "Acordeão de Conta",
        "Account Input": "Entrada de Conta",
        "Add Product": "Adicionar Produto",
        "Are you sure you want to change the pricebook? Changing will remove all already selected items from the list!":
            "Tem certeza de que deseja alterar a lista de preços? Alterar removerá todos os itens já selecionados da lista!",
        "Change Pricebook": "Alterar Lista de Preços",
        "Please fill in the field.": "Por favor, preencha o campo.",
        "First fill in the required fields to proceed...": "Primeiro preencha os campos obrigatórios para continuar...",
        "There was an error in the order!": "Houve um erro no pedido!",
        "Unable to save the order": "Não foi possível salvar o pedido",
        "Error Saving Order": "Erro ao Salvar Pedido",
        "Create Order Header": "Cabeçalho do Pedido",
        "Are you sure you want to delete this order item?": "Tem certeza de que deseja excluir este item do pedido?",
        "Delete Order Item": "Excluir Item do Pedido",
        "Order Items": "Itens do Pedido",
        "You have not selected any items to be displayed, when you have, they will be shown in this area.":
            "Você não selecionou nenhum item para ser exibido, quando selecionar, eles serão mostrados nesta área.",
        "Order Accordion": "Acordeão de Pedido",
        "Pricebook Accordion": "Acordeão de Lista de Preços",
        "Pricebook Input": "Entrada de Lista de Preços",
        "Discount Percentage": "Percentual de Desconto",
        "Total Discount Value": "Valor Total de Desconto",
        "Total Value of the Order": "Valor Total do Pedido",
        "There was an error saving the order": "Houve um erro ao salvar o pedido",
        "Save Order": "Salvar Pedido",
        "Saving order...": "Salvando pedido...",
        "Do you want to save this order?": "Você quer salvar este pedido?",
        "Order saved successfully!": "Pedido salvo com sucesso!",
        "Sending order to Salesforce...": "Enviando pedido para o Salesforce...",
        "There was an error syncing orders": "Houve um erro ao sincronizar os pedidos",
        "Sync Order": "Sincronizar Pedido",
        "Do you want to sync this order?": "Você quer sincronizar este pedido?",
        "ORDER SYNCHRONIZED SUCCESSFULLY!": "PEDIDO SINCRONIZADO COM SUCESSO!",
        "Total Gross Value of the Order": "Valor Bruto Total do Pedido",
        "Update Order": "Atualizar Pedido",
        "Do you want to update this order?": "Você quer atualizar este pedido?",
        "Create Own Brand": "Criar Marca Própria",
        "Create Productive Area": "Criar Área Produtiva",
        "Create Segment": "Criar Segmento",
        "Create Staff": "Criar Equipe",
        "Create Treatment": "Criar Tratamento",
        "Visit": "Visita",
        "Successful visits!": "Visitas bem-sucedidas!",
        "Created": "Criado",
        "Created By Id": "Criado Por Id",
        "Created Successfully": "Criado com Sucesso",
        "Creation Date": "Data de Criação",
        "Creation of Account Revenue": "Criação de Receita de Conta",
        "Creation of Influencers": "Criação de Influenciadores",
        "Creation of Own Brands": "Criação de Marcas Próprias",
        "Creation of Productive Area": "Criação de Área Produtiva",
        "Successfully created!": "Criado com sucesso!",
        "Customer Group": "Grupo de Clientes",
        "Customer list": "Lista de clientes",
        "Customers": "Clientes",
        "Invalid date, please use DD/MM/YYYY": "Data inválida, por favor, use DD/MM/AAAA",
        "December": "Dezembro",
        "Delete": "Excluir",
        "Demand Generation Fields": "Campos de Geração de Demanda",
        "Description": "Descrição",
        "If you confirm, the login process will have to be done again":
            "Se você confirmar, o processo de login terá que ser feito novamente",
        "Details": "Detalhes"
    }
    return translations.get(label_value, label_value)

# Carregar o arquivo XML
tree = ET.parse(r'force-app\main\default\labels\CustomLabels.labels-meta.xml')
root = tree.getroot()

# Espaço de nomes
namespace = {'ns': 'http://soap.sforce.com/2006/04/metadata'}

# Lista para armazenar novas labels
new_labels = []

for label in root.findall('ns:labels', namespace):
    fullName = label.find('ns:fullName', namespace).text
    language = label.find('ns:language', namespace).text
    value = label.find('ns:value', namespace).text
    
    if fullName.startswith("App_Label") and language == "en_US":
        translated_value = translate_label(value)
        new_label = ET.Element('labels')
        
        fullName_elem = ET.SubElement(new_label, 'fullName')
        fullName_elem.text = fullName
        
        language_elem = ET.SubElement(new_label, 'language')
        language_elem.text = 'pt_BR'
        
        protected_elem = ET.SubElement(new_label, 'protected')
        protected_elem.text = label.find('ns:protected', namespace).text
        
        shortDescription_elem = ET.SubElement(new_label, 'shortDescription')
        shortDescription_elem.text = label.find('ns:shortDescription', namespace).text
        
        value_elem = ET.SubElement(new_label, 'value')
        value_elem.text = translated_value
        
        new_labels.append(new_label)

# Adicionar as novas labels ao root
for new_label in new_labels:
    root.append(new_label)

# Salvar o arquivo atualizado
tree.write(r'force-app\main\default\labels\CustomLabels.labels-meta.xml', encoding='UTF-8', xml_declaration=True)
